# %% [markdown]
# # Working with Geolocated Data
# ---

# %% [markdown]
# ### Exercise: Earthquake Monitor

# %% [markdown]
# Collect the data:

# %%
import requests

endpoint = "https://earthquake.usgs.gov/fdsnws/event/1/query?"

ps = { "format": "csv", 
       "starttime": "2025-09-01", 
       "endtime": "2025-09-26",
       "minmagnitude": 5.5
     }

response = requests.get(endpoint, params=ps)

import pandas as pd
import io

buf = io.StringIO(response.text) 
data = pd.read_csv(buf)

# %% [markdown]
# The available information about each earthquake:

# %%
for col in data.columns:
    print(col)
# Out:
# time
# latitude
# longitude
# depth
# mag
# magType
# nst
# gap
# dmin
# rms
# net
# id
# updated
# place
# type
# horizontalError
# depthError
# magError
# magNst
# status
# locationSource
# magSource

# %% [markdown]
# Draw the map:

# %%
import folium

greenwich_coords = [51.4769, 0]  # i.e. [Latitude, Longitude]

world_map = folium.Map(location=greenwich_coords,
                                zoom_start = 1)

# Add markers
for i in range(len(data)):
    quake = data.iloc[i,:]
    folium.Marker(location=[quake.latitude,quake.longitude], 
                  popup = quake.mag
                 ).add_to(world_map)


world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4c5b7d61cc9dd11485a240e20cfd241 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4c5b7d61cc9dd11485a240e20cfd241&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4c5b7d61cc9dd11485a240e20cfd241 = L.map(
#                 &quot;map_a4c5b7d61cc9dd11485a240e20cfd241&quot;,
#                 {
#                     center: [51.4769, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84d3ed637d5f8505edc4a182c6b523dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84d3ed637d5f8505edc4a182c6b523dd.addTo(map_a4c5b7d61cc9dd11485a240e20cfd241);
#
#
#             var marker_4502cc4b1867b16ea80782a7b9b5d181 = L.marker(
#                 [51.422, 157.7944],
#                 {
# }
#             ).addTo(map_a4c5b7d61cc9dd11485a240e20cfd241);
#
#
#         var popup_d1cd203910f7cc95627692b7bdffe7db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce90f3254990f8d8ac0af09556f32a5c = $(`&lt;div id=&quot;html_ce90f3254990f8d8ac0af09556f32a5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.9&lt;/div&gt;`)[0];
#                 popup_d1cd203910f7cc95627692b7bdffe7db.setContent(html_ce90f3254990f8d8ac0af09556f32a5c);
#
#
#
#         marker_4502cc4b1867b16ea80782a7b9b5d181.bindPopup(popup_d1cd203910f7cc95627692b7bdffe7db)
#         ;
#
#
#
#
#             var marker_d67d314b9a0a3e407024872c985606ce = L.marker(
#                 [52.2396, 160.6455],
#                 {
# }
#             ).addTo(map_a4c5b7d61cc9dd11485a240e20cfd241);
#
#
#         var popup_6ec9db3b23b9194f01a0af764cbbcb1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cefddca6a71d1d66d36804f87063dab0 = $(`&lt;div id=&quot;html_cefddca6a71d1d66d36804f87063dab0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.5&lt;/div&gt;`)[0];
#                 popup_6ec9db3b23b9194f01a0af764cbbcb1d.setContent(html_cefddca6a71d1d66d36804f87063dab0);
#
#
#
#         marker_d67d314b9a0a3e407024872c985606ce.bindPopup(popup_6ec9db3b23b9194f01a0af764cbbcb1d)
#         ;
#
#
#
#
#             var marker_d75153fbe15e90177b208b4cbc864f1d = L.marker(
#                 [-20.2187, -69.2907],
#                 {
# }
#             ).addTo(map_a4c5b7d61cc9dd11485a240e20cfd241);
#
#
#         var popup_35f0d08031000f03d27cda6f0742f2a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f252d4463763dc6a2f53432c71c93a6 = $(`&lt;div id=&quot;html_5f252d4463763dc6a2f53432c71c93a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.5&lt;/div&gt;`)[0];
#                 popup_35f0d08031000f03d27cda6f0742f2a5.setContent(html_5f252d4463763dc6a2f53432c71c93a6);
#
#
#
#         marker_d75153fbe15e90177b208b4cbc864f1d.bindPopup(popup_35f0d08031000f03d27cda6f0742f2a5)
#         ;
#
#
#
#
#             var marker_e186bccf6e472eb64e5a08b3cc07c28f = L.marker(
#                 [52.8841, 160.6741],
#                 {
# }
#             ).addTo(map_a4c5b7d61cc9dd11485a240e20cfd241);
#
#
#         var popup_e184272dacf39f0089928486df9fe75b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47dcad0c61813fdef3c225435f20490d = $(`&lt;div id=&quot;html_47dcad0c61813fdef3c225435f20490d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.7&lt;/div&gt;`)[0];
#                 popup_e184272dacf39f0089928486df9fe75b.setContent(html_47dcad0c61813fdef3c225435f20490d);
#
#
#
#         marker_e186bccf6e472eb64e5a08b3cc07c28f.bindPopup(popup_e184272dacf39f0089928486df9fe75b)
#         ;
#
#
#
#
#             var marker_1d9cae8655996756b1b8984fee47d5e1 = L.marker(
#                 [52.3269, 160.7187],
#                 {
# }
#             ).addTo(map_a4c5b7d61cc9dd11485a240e20cfd241);
#
#
#         var popup_1f2d1a98665ce1e4ffa70711743b530f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_973faae65a80c6e7e54333a8e0d1c64a = $(`&lt;div id=&quot;html_973faae65a80c6e7e54333a8e0d1c64a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.6&lt;/div&gt;`)[0];
#                 popup_1f2d1a98665ce1e4ffa70711743b530f.setContent(html_973faae65a80c6e7e54333a8e0d1c64a);
#
#
#
#         marker_1d9cae8655996756b1b8984fee47d5e1.bindPopup(popup_1f2d1a98665ce1e4ffa7071174

# %% [markdown]
# Again but with `folium.CircleMarker`:

# %%
import folium

greenwich_coords = [51.4769, 0]  # i.e. [Latitude, Longitude]

world_map = folium.Map(location=greenwich_coords,
                                zoom_start = 1)

# Add markers
for i in range(len(data)):
    quake = data.iloc[i,:]
    folium.CircleMarker(location=[quake.latitude,quake.longitude], 
                        popup = quake.mag,
                        weight=1,
                        fill=True,
                        fill_opacity=0.3,
                        radius = quake.mag * 2
                       ).add_to(world_map)


world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36393ea8746a85ad1447e79c8d5b422a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36393ea8746a85ad1447e79c8d5b422a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36393ea8746a85ad1447e79c8d5b422a = L.map(
#                 &quot;map_36393ea8746a85ad1447e79c8d5b422a&quot;,
#                 {
#                     center: [51.4769, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1da4d8c52191f9ae5142f910fbc29fcc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1da4d8c52191f9ae5142f910fbc29fcc.addTo(map_36393ea8746a85ad1447e79c8d5b422a);
#
#
#             var circle_marker_b70814870eed0fa5b4636a37cdd6a0cb = L.circleMarker(
#                 [51.422, 157.7944],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.8, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_36393ea8746a85ad1447e79c8d5b422a);
#
#
#         var popup_5a0ced985f513200ced44c22f77dce34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42a617c170220a391457061ca5e881fd = $(`&lt;div id=&quot;html_42a617c170220a391457061ca5e881fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.9&lt;/div&gt;`)[0];
#                 popup_5a0ced985f513200ced44c22f77dce34.setContent(html_42a617c170220a391457061ca5e881fd);
#
#
#
#         circle_marker_b70814870eed0fa5b4636a37cdd6a0cb.bindPopup(popup_5a0ced985f513200ced44c22f77dce34)
#         ;
#
#
#
#
#             var circle_marker_fb07d61238156381c76d5e22011e9713 = L.circleMarker(
#                 [52.2396, 160.6455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_36393ea8746a85ad1447e79c8d5b422a);
#
#
#         var popup_d3709ac28255ba37bf256f848ec94c83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_037a60da921f05f933e3e1ea6c7f5170 = $(`&lt;div id=&quot;html_037a60da921f05f933e3e1ea6c7f5170&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.5&lt;/div&gt;`)[0];
#                 popup_d3709ac28255ba37bf256f848ec94c83.setContent(html_037a60da921f05f933e3e1ea6c7f5170);
#
#
#
#         circle_marker_fb07d61238156381c76d5e22011e9713.bindPopup(popup_d3709ac28255ba37bf256f848ec94c83)
#         ;
#
#
#
#
#             var circle_marker_fc6b46caedf5d001335dae6e301fff48 = L.circleMarker(
#                 [-20.2187, -69.2907],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_36393ea8746a85ad1447e79c8d5b422a);
#
#
#         var popup_5d70c0c8ccdeef1f8bb50033965236c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f0982a736c5fef870470f0d4a79295b = $(`&lt;div id=&quot;html_9f0982a736c5fef870470f0d4a79295b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.5&lt;/div&gt;`)[0];
#                 popup_5d70c0c8ccdeef1f8bb50033965236c5.setContent(html_9f0982a736c5fef870470f0d4a79295b);
#
#
#
#         circle_marker_fc6b46caedf5d001335dae6e301fff48.bindPopup(popup_5d70c0c8ccdeef1f8bb50033965236c5)
#         ;
#
#
#
#
#             var circle_marker_e97dfc17bdc5840d32e318f5b8cb7d3d = L.circleMarker(
#                 [

# %% [markdown]
# For the colouring, we need to request the GeoJSON data:

# %%
endpoint = "https://earthquake.usgs.gov/fdsnws/event/1/query?"

ps = { "format": "geojson", 
       "starttime": "2025-09-01", 
       "endtime": "2025-09-26",
       "minmagnitude": 5.5 
     }

response = requests.get(endpoint, params=ps)

import json
data_dict = json.loads(response.text)

# %% [markdown]
# Let's inspect the first earthquake record:

# %%
quake = data_dict['features'][0]
quake
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 5.9,
#   'place': '90 km E of Ozernovskiy, Russia',
#   'time': 1758293729171,
#   'updated': 1758295581015,
#   'tz': None,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000qxcd',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qxcd&format=geojson',
#   'felt': None,
#   'cdi': None,
#   'mmi': 4.499,
#   'alert': 'green',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 536,
#   'net': 'us',
#   'code': '7000qxcd',
#   'ids': ',usauto7000qxcd,pt25262001,us7000qxcd,',
#   'sources': ',usauto,pt,us,',
#   'types': ',internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#   'nst': 62,
#   'dmin': 1.688,
#   'rms': 0.89,
#   'gap': 116,
#   'magType': 'mww',
#   'type': 'earthquake',
#   'title': 'M 5.9 - 90 km E of Ozernovskiy, Russia'},
#  'geometry': {'type': 'Point', 'coordinates': [157.7944, 51.422, 84.495]},
#  'id': 'us7000qxcd'}

# %% [markdown]
# Notice that the position is given by

# %%
quake['geometry']['coordinates']
# Out:
# [157.7944, 51.422, 84.495]

# %% [markdown]
# which is in the format [longitude, latitude, depth].

# %% [markdown]
# The other information can be retrieved as e.g.

# %%
quake['properties']['mag']
# Out:
# 5.9

# %%
import folium

greenwich_coords = [51.4769, 0]  # i.e. [Latitude, Longitude]

world_map = folium.Map(location=greenwich_coords,
                                zoom_start = 1)

# Add markers
for quake in data_dict['features']:
    coords = quake['geometry']['coordinates']
    folium.CircleMarker(location=[coords[1],coords[0]], 
                        popup = quake['properties']['mag'],
                        weight=1,
                        fill=True,
                        fill_opacity=0.3,
                        color=quake['properties']['alert'],
                        radius = quake['properties']['mag'] * 2
                       ).add_to(world_map)


world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4eaf4d42bace439f92515087ac6fd26b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4eaf4d42bace439f92515087ac6fd26b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4eaf4d42bace439f92515087ac6fd26b = L.map(
#                 &quot;map_4eaf4d42bace439f92515087ac6fd26b&quot;,
#                 {
#                     center: [51.4769, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a87c7f7cdc117cbfee9000e00bdbbfc0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a87c7f7cdc117cbfee9000e00bdbbfc0.addTo(map_4eaf4d42bace439f92515087ac6fd26b);
#
#
#             var circle_marker_22f06ca07ddf1a6ebdedcd5ca90104d5 = L.circleMarker(
#                 [51.422, 157.7944],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.8, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_4eaf4d42bace439f92515087ac6fd26b);
#
#
#         var popup_bb81a082a965ecb59e152195e0c1ab1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6a99c6940048f9a4cf01368aeabb1ee = $(`&lt;div id=&quot;html_f6a99c6940048f9a4cf01368aeabb1ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.9&lt;/div&gt;`)[0];
#                 popup_bb81a082a965ecb59e152195e0c1ab1b.setContent(html_f6a99c6940048f9a4cf01368aeabb1ee);
#
#
#
#         circle_marker_22f06ca07ddf1a6ebdedcd5ca90104d5.bindPopup(popup_bb81a082a965ecb59e152195e0c1ab1b)
#         ;
#
#
#
#
#             var circle_marker_b0ffd27e2a43157d3d26bcb3679a0d41 = L.circleMarker(
#                 [52.2396, 160.6455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_4eaf4d42bace439f92515087ac6fd26b);
#
#
#         var popup_1b6632264597781538e5de5f9609ac09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99e803c08d6f72510844f2899194ea94 = $(`&lt;div id=&quot;html_99e803c08d6f72510844f2899194ea94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.5&lt;/div&gt;`)[0];
#                 popup_1b6632264597781538e5de5f9609ac09.setContent(html_99e803c08d6f72510844f2899194ea94);
#
#
#
#         circle_marker_b0ffd27e2a43157d3d26bcb3679a0d41.bindPopup(popup_1b6632264597781538e5de5f9609ac09)
#         ;
#
#
#
#
#             var circle_marker_3bd25ad09c444ac342f0f5471e400d38 = L.circleMarker(
#                 [-20.2187, -69.2907],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_4eaf4d42bace439f92515087ac6fd26b);
#
#
#         var popup_a8e20dcd00f8656f1c970aea5f368401 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85ff2ea45aa5e28c302149d1681da93d = $(`&lt;div id=&quot;html_85ff2ea45aa5e28c302149d1681da93d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.5&lt;/div&gt;`)[0];
#                 popup_a8e20dcd00f8656f1c970aea5f368401.setContent(html_85ff2ea45aa5e28c302149d1681da93d);
#
#
#
#         circle_marker_3bd25ad09c444ac342f0f5471e400d38.bindPopup(popup_a8e20dcd00f8656f1c970aea5f368401)
#         ;
#
#
#
#
#             var circle_marker_f5f513ea51b9ff4c461004202ff5916e = L.circleMarker(
#                 [52.8841, 160

# %% [markdown]
# # Data Exploration Exercise
# ---

# %%
import pandas as pd
bli = pd.read_csv("../Data/BLI2.csv")

# %% [markdown]
# ---
# ### Task 1
# Do men and women report the same degree of life satisfaction?

# %%
sorted( bli['Indicator'].unique() )
# Out:
# ['Air pollution',
#  'Dwellings without basic facilities',
#  'Educational attainment',
#  'Employees working very long hours',
#  'Employment rate',
#  'Feeling safe walking alone at night',
#  'Homicide rate',
#  'Household net adjusted disposable income',
#  'Household net wealth',
#  'Housing expenditure',
#  'Labour market insecurity',
#  'Life expectancy',
#  'Life satisfaction',
#  'Long-term unemployment rate',
#  'Personal earnings',
#  'Quality of support network',
#  'Rooms per person',
#  'Self-reported health',
#  'Stakeholder engagement for developing regulations',
#  'Student skills',
#  'Time devoted to leisure and personal care',
#  'Voter turnout',
#  'Water quality',
#  'Years in education']

# %% [markdown]
# There is a measure for 'Life satisfaction' so we can do a query to retrieve only these rows:

# %%
data = bli.query("Indicator == 'Life satisfaction'")
data.head()
# Out:
#      LOCATION         Country INDICATOR          Indicator Inequality  \
# 1676      AUS       Australia   SW_LIFS  Life satisfaction      Total
# 1677      AUT         Austria   SW_LIFS  Life satisfaction      Total
# 1678      BEL         Belgium   SW_LIFS  Life satisfaction      Total
# 1679      CAN          Canada   SW_LIFS  Life satisfaction      Total
# 1680      CZE  Czech Republic   SW_LIFS  Life satisfaction      Total
#
#      Unit Code  Value
# 1676   AVSCORE    7.1
# 1677   AVSCORE    7.2
# 1678   AVSCORE    6.8
# 1679   AVSCORE    7.0
# 1680   AVSCORE    6.9

# %% [markdown]
# You can see that the 'Inequality' contains 'Total' measures as well as measures for particular groups.

# %%
sorted( data['Inequality'].unique() )
# Out:
# ['High', 'Low', 'Men', 'Total', 'Women']

# %% [markdown]
# Let's keep only the rows for 'Men' and 'Women'.

# %%
data = data.query("Inequality in ['Men','Women']")
data = data.sort_values('Country')  # to put rows from the same country together
data.head(10)
# Out:
#      LOCATION    Country INDICATOR          Indicator Inequality Unit Code  \
# 1714      AUS  Australia   SW_LIFS  Life satisfaction        Men   AVSCORE
# 1752      AUS  Australia   SW_LIFS  Life satisfaction      Women   AVSCORE
# 1715      AUT    Austria   SW_LIFS  Life satisfaction        Men   AVSCORE
# 1753      AUT    Austria   SW_LIFS  Life satisfaction      Women   AVSCORE
# 1754      BEL    Belgium   SW_LIFS  Life satisfaction      Women   AVSCORE
# 1716      BEL    Belgium   SW_LIFS  Life satisfaction        Men   AVSCORE
# 1782      BRA     Brazil   SW_LIFS  Life satisfaction      Women   AVSCORE
# 1744      BRA     Brazil   SW_LIFS  Life satisfaction        Men   AVSCORE
# 1755      CAN     Canada   SW_LIFS  Life satisfaction      Women   AVSCORE
# 1717      CAN     Canada   SW_LIFS  Life satisfaction        Men   AVSCORE
#
#       Value
# 1714    7.1
# 1752    7.2
# 1715    7.1
# 1753    7.3
# 1754    6.8
# 1716    6.9
# 1782    6.0
# 1744    6.2
# 1755    7.0
# 1717    7.0

# %% [markdown]
# The numbers themselves are in the 'Value' column.
#
# Thinking about the hypothesis test, to compare values for men and women we will need to prepare a paired sample. It makes sense to pivot to make two separate columns for the values:

# %%
reshaped = data.pivot(index='Country',columns='Inequality',values='Value')
reshaped.head()
# Out:
# Inequality  Men  Women
# Country
# Australia   7.1    7.2
# Austria     7.1    7.3
# Belgium     6.9    6.8
# Brazil      6.2    6.0
# Canada      7.0    7.0

# %% [markdown]
# We could visualise them on a histogram:

# %%
import matplotlib.pyplot as plt
plt.hist([reshaped.Men, reshaped.Women],label=['Men','Women'])
plt.legend()
plt.show()

# %%
reshaped.shape
# Out:
# (41, 2)

# %%
reshaped.mean()
# Out:
# Inequality
# Men      6.578049
# Women    6.629268
# dtype: float64

# %% [markdown]
# We can use a paired-sample t-test to check whether this difference in means is significant. (using $\alpha = 0.05$)

# %%
from scipy.stats import ttest_rel
ttest_rel(reshaped.Men,reshaped.Women)
# Out:
# TtestResult(statistic=np.float64(-1.004681192451847), pvalue=np.float64(0.32108965010640494), df=np.int64(40))

# %% [markdown]
# $p > \alpha$: Overall, there does not appear to be any evidence that men and women report significantly different life satisfaction.

# %% [markdown]
# ---
# ### Task 2
# Is life satisfaction related to geographical latitude?
#
# We have some information on the overall 'life satisfaction' of each country:

# %%
life_sat = bli.query("Indicator == 'Life satisfaction' and Inequality == 'Total'")
life_sat
# Out:
#      LOCATION          Country INDICATOR          Indicator Inequality  \
# 1676      AUS        Australia   SW_LIFS  Life satisfaction      Total
# 1677      AUT          Austria   SW_LIFS  Life satisfaction      Total
# 1678      BEL          Belgium   SW_LIFS  Life satisfaction      Total
# 1679      CAN           Canada   SW_LIFS  Life satisfaction      Total
# 1680      CZE   Czech Republic   SW_LIFS  Life satisfaction      Total
# 1681      DNK          Denmark   SW_LIFS  Life satisfaction      Total
# 1682      FIN          Finland   SW_LIFS  Life satisfaction      Total
# 1683      FRA           France   SW_LIFS  Life satisfaction      Total
# 1684      DEU          Germany   SW_LIFS  Life satisfaction      Total
# 1685      GRC           Greece   SW_LIFS  Life satisfaction      Total
# 1686      HUN          Hungary   SW_LIFS  Life satisfaction      Total
# 1687      ISL          Iceland   SW_LIFS  Life satisfaction      Total
# 1688      IRL          Ireland   SW_LIFS  Life satisfaction      Total
# 1689      ITA            Italy   SW_LIFS  Life satisfaction      Total
# 1690      JPN            Japan   SW_LIFS  Life satisfaction      Total
# 1691      KOR            Korea   SW_LIFS  Life satisfaction      Total
# 1692      LUX       Luxembourg   SW_LIFS  Life satisfaction      Total
# 1693      MEX           Mexico   SW_LIFS  Life satisfaction      Total
# 1694      NLD      Netherlands   SW_LIFS  Life satisfaction      Total
# 1695      NZL      New Zealand   SW_LIFS  Life satisfaction      Total
# 1696      NOR           Norway   SW_LIFS  Life satisfaction      Total
# 1697      POL           Poland   SW_LIFS  Life satisfaction      Total
# 1698      PRT         Portugal   SW_LIFS  Life satisfaction      Total
# 1699      SVK  Slovak Republic   SW_LIFS  Life satisfaction      Total
# 1700      ESP            Spain   SW_LIFS  Life satisfaction      Total
# 1701      SWE           Sweden   SW_LIFS  Life satisfaction      Total
# 1702      CHE      Switzerland   SW_LIFS  Life satisfaction      Total
# 1703      TUR          Türkiye   SW_LIFS  Life satisfaction      Total
# 1704      GBR   United Kingdom   SW_LIFS  Life satisfaction      Total
# 1705      USA    United States   SW_LIFS  Life satisfaction      Total
# 1706      BRA           Brazil   SW_LIFS  Life satisfaction      Total
# 1707      CHL            Chile   SW_LIFS  Life satisfaction      Total
# 1708      EST          Estonia   SW_LIFS  Life satisfaction      Total
# 1709      ISR           Israel   SW_LIFS  Life satisfaction      Total
# 1710      LVA           Latvia   SW_LIFS  Life satisfaction      Total
# 1711      RUS           Russia   SW_LIFS  Life satisfaction      Total
# 1712      SVN         Slovenia   SW_LIFS  Life satisfaction      Total
# 1713      ZAF     South Africa   SW_LIFS  Life satisfaction      Total
# 2238      COL         Colombia   SW_LIFS  Life satisfaction      Total
# 2239      LTU        Lithuania   SW_LIFS  Life satisfaction      Total
# 2298      CRI       Costa Rica   SW_LIFS  Life satisfaction      Total
#
#      Unit Code  Value
# 1676   AVSCORE    7.1
# 1677   AVSCORE    7.2
# 1678   AVSCORE    6.8
# 1679   AVSCORE    7.0
# 1680   AVSCORE    6.9
# 1681   AVSCORE    7.5
# 1682   AVSCORE    7.9
# 1683   AVSCORE    6.7
# 1684   AVSCORE    7.3
# 1685   AVSCORE    5.8
# 1686   AVSCORE    6.0
# 1687   AVSCORE    7.6
# 1688   AVSCORE    7.0
# 1689   AVSCORE    6.5
# 1690   AVSCORE    6.1
# 1691   AVSCORE    5.8
# 1692   AVSCORE    7.4
# 1693   AVSCORE    6.0
# 1694   AVSCORE    7.5
# 1695   AVSCORE    7.3
# 1696   AVSCORE    7.3
# 1697   AVSCORE    6.1
# 1698   AVSCORE    5.8
# 1699   AVSCORE    6.5
# 1700   AVSCORE    6.5
# 1701   AVSCORE    7.3
# 1702   AVSCORE    7.5
# 1703   AVSCORE    4.9
# 1704   AVSCORE    6.8
# 1705   AVSCORE    7.0
# 1706   AVSCORE    6.1
# 1707   AVSCORE    6.2
# 1708   AVSCORE    6.5
# 1709   AVSCORE    7.2
# 1710   AVSCORE    6.2
# 1711   AVSCORE    5.5
# 1712   AVSCORE    6.5
# 1713   AVSCORE    4.9
# 2238   AVSCORE    5.7
# 2239   AVSCORE    6.4
# 2298   AVSCORE    6.3

# %% [markdown]
# We also have some information about the latitude of each country (in the *countries* table).

# %%
countries = pd.read_excel("../Data/data_geographies_v1.xlsx", 
                          sheet_name = "list-of-countries-etc")
countries.head()
# Out:
#    geo         name four_regions       eight_regions  \
# 0  afg  Afghanistan         asia           asia_west
# 1  alb      Albania       europe         europe_east
# 2  dza      Algeria       africa        africa_north
# 3  and      Andorra       europe         europe_west
# 4  ago       Angola       africa  africa_sub_saharan
#
#                 six_regions members_oecd_g77  Latitude  Longitude  \
# 0                south_asia              g77  33.00000   66.00000
# 1       europe_central_asia           others  41.00000   20.00000
# 2  middle_east_north_africa              g77  28.00000    3.00000
# 3       europe_central_asia           others  42.50779    1.52109
# 4        sub_saharan_africa              g77 -12.50000   18.50000
#
#   UN member since           World bank region World bank, 4 income groups 2017
# 0      1946-11-19                  South Asia                       Low income
# 1      1955-12-14       Europe & Central Asia              Upper middle income
# 2      1962-10-08  Middle East & North Africa              Upper middle income
# 3      1993-07-28       Europe & Central Asia                      High income
# 4      1976-12-01          Sub-Saharan Africa              Lower middle income

# %% [markdown]
# Can we combine these somehow to answer this question?
#
# How do we work with data that are held in two different DataFrames? It will be tricky at the moment, but fortunately pandas has some more tools to help us!

# %% [markdown]
# ### Joining tables
#
# We will start with the *life_sat* DataFrame (the "left-hand" table) and add the 'Latitude' column from *countries*. To do this, we need to `join()` the two tables together.
#
# Importantly, we **cannot** assume that the countries are listed in the same order, or even that both tables contain the same set of countries. We need to identify a *key*, that is, some information that exists in both tables, that we can use to "look up" the correct row from *countries* (the "right-hand" table).
#
# For our current task, the key is simply the country name.
# We make these columns the index of both the left and right tables:

# %%
left = life_sat.copy()
left['geo'] = left['LOCATION'].str.lower()
left = left.set_index('geo')
left.head()
# Out:
#     LOCATION         Country INDICATOR          Indicator Inequality  \
# geo
# aus      AUS       Australia   SW_LIFS  Life satisfaction      Total
# aut      AUT         Austria   SW_LIFS  Life satisfaction      Total
# bel      BEL         Belgium   SW_LIFS  Life satisfaction      Total
# can      CAN          Canada   SW_LIFS  Life satisfaction      Total
# cze      CZE  Czech Republic   SW_LIFS  Life satisfaction      Total
#
#     Unit Code  Value
# geo
# aus   AVSCORE    7.1
# aut   AVSCORE    7.2
# bel   AVSCORE    6.8
# can   AVSCORE    7.0
# cze   AVSCORE    6.9

# %%
right = countries.set_index('geo')
right = right[['Latitude']]  # to keep only the Latitude column
right.head()
# Out:
#      Latitude
# geo
# afg  33.00000
# alb  41.00000
# dza  28.00000
# and  42.50779
# ago -12.50000

# %% [markdown]
# Now we can join them with the `join()` method!

# %%
joined = left.join(right)
joined
# Out:
#     LOCATION          Country INDICATOR          Indicator Inequality  \
# geo
# aus      AUS        Australia   SW_LIFS  Life satisfaction      Total
# aut      AUT          Austria   SW_LIFS  Life satisfaction      Total
# bel      BEL          Belgium   SW_LIFS  Life satisfaction      Total
# can      CAN           Canada   SW_LIFS  Life satisfaction      Total
# cze      CZE   Czech Republic   SW_LIFS  Life satisfaction      Total
# dnk      DNK          Denmark   SW_LIFS  Life satisfaction      Total
# fin      FIN          Finland   SW_LIFS  Life satisfaction      Total
# fra      FRA           France   SW_LIFS  Life satisfaction      Total
# deu      DEU          Germany   SW_LIFS  Life satisfaction      Total
# grc      GRC           Greece   SW_LIFS  Life satisfaction      Total
# hun      HUN          Hungary   SW_LIFS  Life satisfaction      Total
# isl      ISL          Iceland   SW_LIFS  Life satisfaction      Total
# irl      IRL          Ireland   SW_LIFS  Life satisfaction      Total
# ita      ITA            Italy   SW_LIFS  Life satisfaction      Total
# jpn      JPN            Japan   SW_LIFS  Life satisfaction      Total
# kor      KOR            Korea   SW_LIFS  Life satisfaction      Total
# lux      LUX       Luxembourg   SW_LIFS  Life satisfaction      Total
# mex      MEX           Mexico   SW_LIFS  Life satisfaction      Total
# nld      NLD      Netherlands   SW_LIFS  Life satisfaction      Total
# nzl      NZL      New Zealand   SW_LIFS  Life satisfaction      Total
# nor      NOR           Norway   SW_LIFS  Life satisfaction      Total
# pol      POL           Poland   SW_LIFS  Life satisfaction      Total
# prt      PRT         Portugal   SW_LIFS  Life satisfaction      Total
# svk      SVK  Slovak Republic   SW_LIFS  Life satisfaction      Total
# esp      ESP            Spain   SW_LIFS  Life satisfaction      Total
# swe      SWE           Sweden   SW_LIFS  Life satisfaction      Total
# che      CHE      Switzerland   SW_LIFS  Life satisfaction      Total
# tur      TUR          Türkiye   SW_LIFS  Life satisfaction      Total
# gbr      GBR   United Kingdom   SW_LIFS  Life satisfaction      Total
# usa      USA    United States   SW_LIFS  Life satisfaction      Total
# bra      BRA           Brazil   SW_LIFS  Life satisfaction      Total
# chl      CHL            Chile   SW_LIFS  Life satisfaction      Total
# est      EST          Estonia   SW_LIFS  Life satisfaction      Total
# isr      ISR           Israel   SW_LIFS  Life satisfaction      Total
# lva      LVA           Latvia   SW_LIFS  Life satisfaction      Total
# rus      RUS           Russia   SW_LIFS  Life satisfaction      Total
# svn      SVN         Slovenia   SW_LIFS  Life satisfaction      Total
# zaf      ZAF     South Africa   SW_LIFS  Life satisfaction      Total
# col      COL         Colombia   SW_LIFS  Life satisfaction      Total
# ltu      LTU        Lithuania   SW_LIFS  Life satisfaction      Total
# cri      CRI       Costa Rica   SW_LIFS  Life satisfaction      Total
#
#     Unit Code  Value  Latitude
# geo
# aus   AVSCORE    7.1 -25.00000
# aut   AVSCORE    7.2  47.33333
# bel   AVSCORE    6.8  50.75000
# can   AVSCORE    7.0  60.10867
# cze   AVSCORE    6.9  49.75000
# dnk   AVSCORE    7.5  56.00000
# fin   AVSCORE    7.9  64.00000
# fra   AVSCORE    6.7  46.00000
# deu   AVSCORE    7.3  51.50000
# grc   AVSCORE    5.8  39.00000
# hun   AVSCORE    6.0  47.00000
# isl   AVSCORE    7.6  65.00000
# irl   AVSCORE    7.0  53.00000
# ita   AVSCORE    6.5  42.83333
# jpn   AVSCORE    6.1  35.68536
# kor   AVSCORE    5.8  36.50000
# lux   AVSCORE    7.4  49.61167
# mex   AVSCORE    6.0  19.42847
# nld   AVSCORE    7.5  52.25000
# nzl   AVSCORE    7.3 -42.00000
# nor   AVSCORE    7.3  62.00000
# pol   AVSCORE    6.1  52.00000
# prt   AVSCORE    5.8  39.69450
# svk   AVSCORE    6.5  48.66667
# esp   AVSCORE    6.5  40.00000
# swe   AVSCORE    7.3  62.00000
# che   AVSCORE    7.5  47.00016
# tur   AVSCORE    4.9  39.00000
# gbr   AVSCORE    6.8  54.75844
# usa   AVSCORE    7.0  39.76000
# bra   AVSCORE    6.1 -10.00000
# chl   AVSCORE    6.2 -33.45694
# est   AVSCORE    6.5  59.00000
# isr   AVSCORE    7.2  31.50000
# lva   AVSCORE    6.2  57.00000
# rus   AVSCORE    5.5  60.00000
# svn   AVSCORE    6.5  46.08333
# zaf   AVSCORE    4.9 -29.00000
# col   AVSCORE    5.7   4.00000
# ltu   AVSCORE    6.4  55.41667
# cri   AVSCORE    6.3  10.00000

# %% [markdown]
# `join()` is just one of several pandas methods for working with **relational data** (i.e. data held in more than one table).
#
# You can move the the current index column back into the body of the DataFrame using the method [`reset_index()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html?highlight=reset_index#pandas.DataFrame.reset_index)

# %%
data = joined.reset_index()
data.head()
# Out:
#    geo LOCATION         Country INDICATOR          Indicator Inequality  \
# 0  aus      AUS       Australia   SW_LIFS  Life satisfaction      Total
# 1  aut      AUT         Austria   SW_LIFS  Life satisfaction      Total
# 2  bel      BEL         Belgium   SW_LIFS  Life satisfaction      Total
# 3  can      CAN          Canada   SW_LIFS  Life satisfaction      Total
# 4  cze      CZE  Czech Republic   SW_LIFS  Life satisfaction      Total
#
#   Unit Code  Value  Latitude
# 0   AVSCORE    7.1 -25.00000
# 1   AVSCORE    7.2  47.33333
# 2   AVSCORE    6.8  50.75000
# 3   AVSCORE    7.0  60.10867
# 4   AVSCORE    6.9  49.75000

# %% [markdown]
# Use the resulting table to investigate the relationship between life satisfaction and latitude.

# %%
import numpy as np
plt.scatter(data['Value'],data['Latitude'])
plt.show()

# %% [markdown]
# The shape of the data looks interesting. What if we take the absolute value of Latitude using `np.abs()`?

# %%
import numpy as np
plt.scatter(data['Value'],np.abs(data['Latitude']))
plt.show()

# %% [markdown]
# It looks like there is a positive correlation between abs(Latitude) and life satisfaction. We can check this with Pearson's $r$. Remember that the function also reports a p-value:

# %%
from scipy.stats import pearsonr
r, pval = pearsonr(data['Value'],np.abs(data['Latitude']))
print("r =",r)
print("pval =",pval)
# Out:
# r = 0.46745633313987595
# pval = 0.002059332251062298

# %% [markdown]
# The correlation looks significant at a significance level of $\alpha=0.05$.

# %% [markdown]
# ### Question:
# What is the origin of this correlation?

# %% [markdown]
# Of course, there are many factors that we have not yet considered. If we look carefully at the scatter plot, the correlation is mostly caused by the points where abs(Latitude) < 30 degrees:

# %%
plt.scatter(data['Value'],np.abs(data['Latitude']))
plt.plot([4.5,8.5],[30,30], c='gray')
plt.show()

# %% [markdown]
# Which countries have abs(Latitude) < 30 degrees?

# %%
data.query("Latitude > -30 and Latitude < 30")['Country']
# Out:
# 0        Australia
# 17          Mexico
# 30          Brazil
# 37    South Africa
# 38        Colombia
# 40      Costa Rica
# Name: Country, dtype: object

# %% [markdown]
# We might propose a hypothesis that being formerly colonised by a European country (rather than e.g. amount of sunshine) is associated with lower life satisfaction.
#
# Since we have derived this hypothesis **after** looking at the data, we cannot test it on the same data set. But there are lots of other countries that are not in our current table, so it would still be possible to test this idea on another data set.

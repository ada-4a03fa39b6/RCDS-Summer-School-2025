# %% [markdown]
# # HTTP Requests
# ---
# This notebook introduces the `requests` library, which we can use to retrieve data from the web.

# %% [markdown]
# Some data resources are provided online as **APIs** (Application Programming Interfaces), which can be accessed using a protocol called HTTP (HyperText Transfer Protocol). These interfaces may allow us to retrieve information in various ways, for example by asking for a particular record or making a search.
#
# In this notebook we will look at an API provided by the [US Geological Survey](https://www.usgs.gov/programs/earthquake-hazards) providing continually-updated information about earthquakes around the world.
#
# Firstly, take a look at the web form for searching manually. Go to https://earthquake.usgs.gov/earthquakes/search/
#
# Notice all of the different search options and try some searches out.
#
# The results are presented as a list and an interactive map.
#
# <img src='../resources/earthquakes.png'>

# %% [markdown]
# ---
# ## Making a request
# But what if we want to retrieve the data themselves? Here is an example using `requests`:

# %%
import requests

# An endpoint is a URL that accepts requests
endpoint = "https://earthquake.usgs.gov/fdsnws/event/1/query?"

# The parameters for our search, in the form of a dictionary
ps = { "format": "csv", 
       "starttime": "2025-09-01", 
       "endtime": "2025-09-26",
       "minmagnitude": 6.0  
     }

response = requests.get(endpoint, params=ps)

print(response.text)
# Out:
# time,latitude,longitude,depth,mag,magType,nst,gap,dmin,rms,net,id,updated,place,type,horizontalError,depthError,magError,magNst,status,locationSource,magSource
# 2025-09-25T03:51:39.731Z,9.9272,-70.6916,14,6.3,mww,107,24,1.038,1.09,us,us6000rcqw,2025-09-25T22:49:34.774Z,"27 km ENE of Mene Grande, Venezuela",earthquake,7.35,1.724,0.027,130,reviewed,us,us
# 2025-09-24T22:21:55.207Z,9.9222,-70.7174,7.815,6.2,mww,61,55,1.035,1.03,us,us6000rcnw,2025-09-25T22:29:26.726Z,"24 km ENE of Mene Grande, Venezuela",earthquake,5.27,6.004,0.052,36,reviewed,us,us
# 2025-09-18T18:58:13.903Z,53.1928,160.5129,19.5,7.8,mww,201,27,1.136,0.85,us,us7000qx2g,2025-09-22T02:07:38.065Z,"127 km E of Petropavlovsk-Kamchatsky, Russia",earthquake,8.42,1.736,0.031,99,reviewed,us,us
# 2025-09-18T18:19:46.543Z,-3.6145,135.5258,10,6.1,mww,84,36,1.319,0.93,us,us7000qx1z,2025-09-19T18:44:14.420Z,"28 km S of Nabire, Indonesia",earthquake,5.93,1.843,0.039,63,reviewed,us,us
# 2025-09-16T16:59:47.665Z,-5.4051,153.825,41.023,6,mww,187,21,2.048,0.74,us,us7000qwir,2025-09-18T21:29:52.147Z,"208 km SE of Kokopo, Papua New Guinea",earthquake,7.15,4.35,0.042,55,reviewed,us,us
# 2025-09-15T16:34:36.629Z,52.6922,160.7026,24.472,6,mww,130,105,1.288,0.7,us,us7000qwch,2025-09-16T21:34:35.804Z,"145 km ESE of Petropavlovsk-Kamchatsky, Russia",earthquake,7.11,5.01,0.069,20,reviewed,us,us
# 2025-09-13T02:37:54.754Z,53.1043,160.2938,39.465,7.4,mww,104,43,0.995,1.11,us,us7000qvw5,2025-09-22T06:05:32.567Z,"111 km E of Petropavlovsk-Kamchatsky, Russia",earthquake,8.91,6.189,0.033,89,reviewed,us,us
# 2025-09-08T21:47:48.083Z,-21.0251,173.7122,10,6.4,mww,78,52,5.237,0.58,us,us7000quvp,2025-09-11T19:30:59.254Z,"Vanuatu region",earthquake,7.7,1.751,0.036,76,reviewed,us,us
# 2025-09-03T20:57:46.971Z,52.3338,-169.6766,10,6,mww,105,60,0.812,0.73,us,us7000qtm0,2025-09-25T21:07:54.454Z,"87 km SW of Nikolski, Alaska",earthquake,7.15,1.836,0.045,48,reviewed,us,us

# %% [markdown]
# An *endpoint* is a particular URL (web address) that will accept a request in a particular format and return a *response*.
#
# The USGS endpoint is able to return data in CSV format, which we can access using the `.text` attribute.
#
# The parameter options for this endpoint are explained
# [here](https://earthquake.usgs.gov/fdsnws/event/1/?ref=springboard).

# %% [markdown]
# ---
# ## Converting to a DataFrame
# If we want to create a DataFrame from this CSV text, we can do the following:

# %%
import pandas as pd
import io

# make a string buffer from the CSV text
buf = io.StringIO(response.text) 

# pandas can now read the data from the buffer
data = pd.read_csv(buf)          

data
# Out:
#                        time  latitude  longitude   depth  mag magType  nst  \
# 0  2025-09-25T03:51:39.731Z    9.9272   -70.6916  14.000  6.3     mww  107
# 1  2025-09-24T22:21:55.207Z    9.9222   -70.7174   7.815  6.2     mww   61
# 2  2025-09-18T18:58:13.903Z   53.1928   160.5129  19.500  7.8     mww  201
# 3  2025-09-18T18:19:46.543Z   -3.6145   135.5258  10.000  6.1     mww   84
# 4  2025-09-16T16:59:47.665Z   -5.4051   153.8250  41.023  6.0     mww  187
# 5  2025-09-15T16:34:36.629Z   52.6922   160.7026  24.472  6.0     mww  130
# 6  2025-09-13T02:37:54.754Z   53.1043   160.2938  39.465  7.4     mww  104
# 7  2025-09-08T21:47:48.083Z  -21.0251   173.7122  10.000  6.4     mww   78
# 8  2025-09-03T20:57:46.971Z   52.3338  -169.6766  10.000  6.0     mww  105
#
#    gap   dmin   rms  ...                   updated  \
# 0   24  1.038  1.09  ...  2025-09-25T22:49:34.774Z
# 1   55  1.035  1.03  ...  2025-09-25T22:29:26.726Z
# 2   27  1.136  0.85  ...  2025-09-22T02:07:38.065Z
# 3   36  1.319  0.93  ...  2025-09-19T18:44:14.420Z
# 4   21  2.048  0.74  ...  2025-09-18T21:29:52.147Z
# 5  105  1.288  0.70  ...  2025-09-16T21:34:35.804Z
# 6   43  0.995  1.11  ...  2025-09-22T06:05:32.567Z
# 7   52  5.237  0.58  ...  2025-09-11T19:30:59.254Z
# 8   60  0.812  0.73  ...  2025-09-25T21:07:54.454Z
#
#                                             place        type horizontalError  \
# 0             27 km ENE of Mene Grande, Venezuela  earthquake            7.35
# 1             24 km ENE of Mene Grande, Venezuela  earthquake            5.27
# 2    127 km E of Petropavlovsk-Kamchatsky, Russia  earthquake            8.42
# 3                    28 km S of Nabire, Indonesia  earthquake            5.93
# 4           208 km SE of Kokopo, Papua New Guinea  earthquake            7.15
# 5  145 km ESE of Petropavlovsk-Kamchatsky, Russia  earthquake            7.11
# 6    111 km E of Petropavlovsk-Kamchatsky, Russia  earthquake            8.91
# 7                                  Vanuatu region  earthquake            7.70
# 8                    87 km SW of Nikolski, Alaska  earthquake            7.15
#
#   depthError  magError  magNst    status  locationSource magSource
# 0      1.724     0.027     130  reviewed              us        us
# 1      6.004     0.052      36  reviewed              us        us
# 2      1.736     0.031      99  reviewed              us        us
# 3      1.843     0.039      63  reviewed              us        us
# 4      4.350     0.042      55  reviewed              us        us
# 5      5.010     0.069      20  reviewed              us        us
# 6      6.189     0.033      89  reviewed              us        us
# 7      1.751     0.036      76  reviewed              us        us
# 8      1.836     0.045      48  reviewed              us        us
#
# [9 rows x 22 columns]

# %% [markdown]
# ---
# ### JSON
#
# We are getting comfortable with CSV format, but there are many other data formats that are in common use.
#
# When working with APIs, we often encounter the **JSON** (JavaScript Object Notation) format.
#
# The USGS endpoint can return responses in [GeoJSON](https://en.wikipedia.org/wiki/GeoJSON), a particular flavour of JSON which is used to describe geolocated objects.

# %%
endpoint = "https://earthquake.usgs.gov/fdsnws/event/1/query?"

ps = { "format": "geojson", 
       "starttime": "2025-09-01", 
       "endtime": "2025-09-26",
       "minmagnitude": 6.0  
     }

response = requests.get(endpoint, params=ps)

print(response.text)
# Out:
# {"type":"FeatureCollection","metadata":{"generated":1758884614000,"url":"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2025-09-01&endtime=2025-09-26&minmagnitude=6.0","title":"USGS Earthquakes","status":200,"api":"1.14.1","count":9},"features":[{"type":"Feature","properties":{"mag":6.3,"place":"27 km ENE of Mene Grande, Venezuela","time":1758772299731,"updated":1758840574774,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us6000rcqw","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rcqw&format=geojson","felt":220,"cdi":8.7,"mmi":7.744,"alert":"yellow","status":"reviewed","tsunami":1,"sig":841,"net":"us","code":"6000rcqw","ids":",pt25268000,us6000rcqw,at00t34le6,usauto6000rcqw,","sources":",pt,us,at,usauto,","types":",dyfi,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,","nst":107,"dmin":1.038,"rms":1.09,"gap":24,"magType":"mww","type":"earthquake","title":"M 6.3 - 27 km ENE of Mene Grande, Venezuela"},"geometry":{"type":"Point","coordinates":[-70.6916,9.9272,14]},"id":"us6000rcqw"},
# {"type":"Feature","properties":{"mag":6.2,"place":"24 km ENE of Mene Grande, Venezuela","time":1758752515207,"updated":1758839366726,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us6000rcnw","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rcnw&format=geojson","felt":242,"cdi":8.6,"mmi":7.827,"alert":"yellow","status":"reviewed","tsunami":1,"sig":858,"net":"us","code":"6000rcnw","ids":",pt25267000,us6000rcnw,at00t3464l,usauto6000rcnw,","sources":",pt,us,at,usauto,","types":",dyfi,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,","nst":61,"dmin":1.035,"rms":1.03,"gap":55,"magType":"mww","type":"earthquake","title":"M 6.2 - 24 km ENE of Mene Grande, Venezuela"},"geometry":{"type":"Point","coordinates":[-70.7174,9.9222,7.815]},"id":"us6000rcnw"},
# {"type":"Feature","properties":{"mag":7.8,"place":"127 km E of Petropavlovsk-Kamchatsky, Russia","time":1758221893903,"updated":1758506858065,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us7000qx2g","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qx2g&format=geojson","felt":26,"cdi":8.7,"mmi":8.358,"alert":"orange","status":"reviewed","tsunami":1,"sig":1023,"net":"us","code":"7000qx2g","ids":",at00t2ssp5,us7000qx2g,pt25261001,usauto7000qx2g,","sources":",at,us,pt,usauto,","types":",dyfi,finite-fault,general-text,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,","nst":201,"dmin":1.136,"rms":0.85,"gap":27,"magType":"mww","type":"earthquake","title":"M 7.8 - 127 km E of Petropavlovsk-Kamchatsky, Russia"},"geometry":{"type":"Point","coordinates":[160.5129,53.1928,19.5]},"id":"us7000qx2g"},
# {"type":"Feature","properties":{"mag":6.1,"place":"28 km S of Nabire, Indonesia","time":1758219586543,"updated":1758307454420,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us7000qx1z","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qx1z&format=geojson","felt":6,"cdi":8.7,"mmi":7.554,"alert":"green","status":"reviewed","tsunami":0,"sig":578,"net":"us","code":"7000qx1z","ids":",us7000qx1z,usauto7000qx1z,pt25261000,","sources":",us,usauto,pt,","types":",dyfi,ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,","nst":84,"dmin":1.319,"rms":0.93,"gap":36,"magType":"mww","type":"earthquake","title":"M 6.1 - 28 km S of Nabire, Indonesia"},"geometry":{"type":"Point","coordinates":[135.5258,-3.6145,10]},"id":"us7000qx1z"},
# {"type":"Feature","properties":{"mag":6,"place":"208 km SE of Kokopo, Papua New Guinea","time":1758041987665,"updated":1758230992147,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us7000qwir","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qwir&format=geojson","felt":null,"cdi":null,"mmi":4.199,"alert":"green","status":"reviewed","tsunami":0,"sig":554,"net":"us","code":"7000qwir","ids":",us7000qwir,usauto7000qwir,at00t2oxvr,pt25259000,","sources":",us,usauto,at,pt,","types":",ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,","nst":187,"dmin":2.048,"rms":0.74,"gap":21,"magType":"mww","type":"earthquake","title":"M 6.0 - 208 km SE of Kokopo, Papua New Guinea"},"geometry":{"type":"Point","coordinates":[153.825,-5.4051,41.023]},"id":"us7000qwir"},
# {"type":"Feature","properties":{"mag":6,"place":"145 km ESE of Petropavlovsk-Kamchatsky, Russia","time":1757954076629,"updated":1758058475804,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us7000qwch","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qwch&format=geojson","felt":null,"cdi":null,"mmi":4.166,"alert":"green","status":"reviewed","tsunami":0,"sig":554,"net":"us","code":"7000qwch","ids":",us7000qwch,usauto7000qwch,at00t2n21p,pt25258001,","sources":",us,usauto,at,pt,","types":",ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,","nst":130,"dmin":1.288,"rms":0.7,"gap":105,"magType":"mww","type":"earthquake","title":"M 6.0 - 145 km ESE of Petropavlovsk-Kamchatsky, Russia"},"geometry":{"type":"Point","coordinates":[160.7026,52.6922,24.472]},"id":"us7000qwch"},
# {"type":"Feature","properties":{"mag":7.4,"place":"111 km E of Petropavlovsk-Kamchatsky, Russia","time":1757731074754,"updated":1758521132567,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us7000qvw5","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qvw5&format=geojson","felt":19,"cdi":8.2,"mmi":6.352,"alert":"green","status":"reviewed","tsunami":1,"sig":858,"net":"us","code":"7000qvw5","ids":",us7000qvw5,at00t2i9z8,pt25256000,usauto7000qvw5,","sources":",us,at,pt,usauto,","types":",dyfi,finite-fault,general-text,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,","nst":104,"dmin":0.995,"rms":1.11,"gap":43,"magType":"mww","type":"earthquake","title":"M 7.4 - 111 km E of Petropavlovsk-Kamchatsky, Russia"},"geometry":{"type":"Point","coordinates":[160.2938,53.1043,39.465]},"id":"us7000qvw5"},
# {"type":"Feature","properties":{"mag":6.4,"place":"Vanuatu region","time":1757368068083,"updated":1757619059254,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us7000quvp","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000quvp&format=geojson","felt":1,"cdi":3.1,"mmi":3.904,"alert":"green","status":"reviewed","tsunami":1,"sig":630,"net":"us","code":"7000quvp","ids":",us7000quvp,pt25251000,at00t2ahvu,usauto7000quvp,","sources":",us,pt,at,usauto,","types":",dyfi,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,","nst":78,"dmin":5.237,"rms":0.58,"gap":52,"magType":"mww","type":"earthquake","title":"M 6.4 - Vanuatu region"},"geometry":{"type":"Point","coordinates":[173.7122,-21.0251,10]},"id":"us7000quvp"},
# {"type":"Feature","properties":{"mag":6,"place":"87 km SW of Nikolski, Alaska","time":1756933066971,"updated":1758834474454,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us7000qtm0","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qtm0&format=geojson","felt":null,"cdi":null,"mmi":4.18,"alert":"green","status":"reviewed","tsunami":1,"sig":554,"net":"us","code":"7000qtm0","ids":",at00t2168g,ak025bb6gdes,us7000qtm0,usauto7000qtm0,pt25246000,","sources":",at,ak,us,usauto,pt,","types":",ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,oaf,origin,phase-data,shakemap,","nst":105,"dmin":0.812,"rms":0.73,"gap":60,"magType":"mww","type":"earthquake","title":"M 6.0 - 87 km SW of Nikolski, Alaska"},"geometry":{"type":"Point","coordinates":[-169.6766,52.3338,10]},"id":"us7000qtm0"}],"bbox":[-169.6766,-21.0251,7.815,173.7122,53.1928,41.023]}

# %% [markdown]
# Notice that JSON data consists of nested dictionaries (marked by **{ }**) and lists (marked by **\[ ]**).
# It is a very flexible format, and can be used to describe data structures that are more complex than just tables.

# %% [markdown]
# If you need to work with JSON data, the built-in `json` module is very handy.

# %%
import json
data_dict = json.loads(response.text)
data_dict
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1758884614000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2025-09-01&endtime=2025-09-26&minmagnitude=6.0',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.14.1',
#   'count': 9},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '27 km ENE of Mene Grande, Venezuela',
#     'time': 1758772299731,
#     'updated': 1758840574774,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rcqw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rcqw&format=geojson',
#     'felt': 220,
#     'cdi': 8.7,
#     'mmi': 7.744,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 841,
#     'net': 'us',
#     'code': '6000rcqw',
#     'ids': ',pt25268000,us6000rcqw,at00t34le6,usauto6000rcqw,',
#     'sources': ',pt,us,at,usauto,',
#     'types': ',dyfi,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 107,
#     'dmin': 1.038,
#     'rms': 1.09,
#     'gap': 24,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 27 km ENE of Mene Grande, Venezuela'},
#    'geometry': {'type': 'Point', 'coordinates': [-70.6916, 9.9272, 14]},
#    'id': 'us6000rcqw'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.2,
#     'place': '24 km ENE of Mene Grande, Venezuela',
#     'time': 1758752515207,
#     'updated': 1758839366726,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rcnw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rcnw&format=geojson',
#     'felt': 242,
#     'cdi': 8.6,
#     'mmi': 7.827,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 858,
#     'net': 'us',
#     'code': '6000rcnw',
#     'ids': ',pt25267000,us6000rcnw,at00t3464l,usauto6000rcnw,',
#     'sources': ',pt,us,at,usauto,',
#     'types': ',dyfi,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 61,
#     'dmin': 1.035,
#     'rms': 1.03,
#     'gap': 55,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.2 - 24 km ENE of Mene Grande, Venezuela'},
#    'geometry': {'type': 'Point', 'coordinates': [-70.7174, 9.9222, 7.815]},
#    'id': 'us6000rcnw'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.8,
#     'place': '127 km E of Petropavlovsk-Kamchatsky, Russia',
#     'time': 1758221893903,
#     'updated': 1758506858065,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000qx2g',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qx2g&format=geojson',
#     'felt': 26,
#     'cdi': 8.7,
#     'mmi': 8.358,
#     'alert': 'orange',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1023,
#     'net': 'us',
#     'code': '7000qx2g',
#     'ids': ',at00t2ssp5,us7000qx2g,pt25261001,usauto7000qx2g,',
#     'sources': ',at,us,pt,usauto,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 201,
#     'dmin': 1.136,
#     'rms': 0.85,
#     'gap': 27,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.8 - 127 km E of Petropavlovsk-Kamchatsky, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [160.5129, 53.1928, 19.5]},
#    'id': 'us7000qx2g'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': '28 km S of Nabire, Indonesia',
#     'time': 1758219586543,
#     'updated': 1758307454420,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000qx1z',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qx1z&format=geojson',
#     'felt': 6,
#     'cdi': 8.7,
#     'mmi': 7.554,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 578,
#     'net': 'us',
#     'code': '7000qx1z',
#     'ids': ',us7000qx1z,usauto7000qx1z,pt25261000,',
#     'sources': ',us,usauto,pt,',
#     'types': ',dyfi,ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 84,
#     'dmin': 1.319,
#     'rms': 0.93,
#     'gap': 36,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - 28 km S of Nabire, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [135.5258, -3.6145, 10]},
#    'id': 'us7000qx1z'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '208 km SE of Kokopo, Papua New Guinea',
#     'time': 1758041987665,
#     'updated': 1758230992147,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000qwir',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qwir&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4.199,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '7000qwir',
#     'ids': ',us7000qwir,usauto7000qwir,at00t2oxvr,pt25259000,',
#     'sources': ',us,usauto,at,pt,',
#     'types': ',ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 187,
#     'dmin': 2.048,
#     'rms': 0.74,
#     'gap': 21,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 208 km SE of Kokopo, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [153.825, -5.4051, 41.023]},
#    'id': 'us7000qwir'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '145 km ESE of Petropavlovsk-Kamchatsky, Russia',
#     'time': 1757954076629,
#     'updated': 1758058475804,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000qwch',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qwch&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4.166,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '7000qwch',
#     'ids': ',us7000qwch,usauto7000qwch,at00t2n21p,pt25258001,',
#     'sources': ',us,usauto,at,pt,',
#     'types': ',ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 130,
#     'dmin': 1.288,
#     'rms': 0.7,
#     'gap': 105,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 145 km ESE of Petropavlovsk-Kamchatsky, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [160.7026, 52.6922, 24.472]},
#    'id': 'us7000qwch'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.4,
#     'place': '111 km E of Petropavlovsk-Kamchatsky, Russia',
#     'time': 1757731074754,
#     'updated': 1758521132567,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000qvw5',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qvw5&format=geojson',
#     'felt': 19,
#     'cdi': 8.2,
#     'mmi': 6.352,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 858,
#     'net': 'us',
#     'code': '7000qvw5',
#     'ids': ',us7000qvw5,at00t2i9z8,pt25256000,usauto7000qvw5,',
#     'sources': ',us,at,pt,usauto,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 104,
#     'dmin': 0.995,
#     'rms': 1.11,
#     'gap': 43,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.4 - 111 km E of Petropavlovsk-Kamchatsky, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [160.2938, 53.1043, 39.465]},
#    'id': 'us7000qvw5'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.4,
#     'place': 'Vanuatu region',
#     'time': 1757368068083,
#     'updated': 1757619059254,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000quvp',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000quvp&format=geojson',
#     'felt': 1,
#     'cdi': 3.1,
#     'mmi': 3.904,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 630,
#     'net': 'us',
#     'code': '7000quvp',
#     'ids': ',us7000quvp,pt25251000,at00t2ahvu,usauto7000quvp,',
#     'sources': ',us,pt,at,usauto,',
#     'types': ',dyfi,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 78,
#     'dmin': 5.237,
#     'rms': 0.58,
#     'gap': 52,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.4 - Vanuatu region'},
#    'geometry': {'type': 'Point', 'coordinates': [173.7122, -21.0251, 10]},
#    'id': 'us7000quvp'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '87 km SW of Nikolski, Alaska',
#     'time': 1756933066971,
#     'updated': 1758834474454,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000qtm0',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000qtm0&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4.18,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 554,
#     'net': 'us',
#     'code': '7000qtm0',
#     'ids': ',at00t2168g,ak025bb6gdes,us7000qtm0,usauto7000qtm0,pt25246000,',
#     'sources': ',at,ak,us,usauto,pt,',
#     'types': ',ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,oaf,origin,phase-data,shakemap,',
#     'nst': 105,
#     'dmin': 0.812,
#     'rms': 0.73,
#     'gap': 60,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 87 km SW of Nikolski, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-169.6766, 52.3338, 10]},
#    'id': 'us7000qtm0'}],
#  'bbox': [-169.6766, -21.0251, 7.815, 173.7122, 53.1928, 41.023]}

# %% [markdown]
# *data_dict* is now just a python dictionary, which we can manipulate as we like.
# For example, to print the magnitude of all earthquakes in the response:

# %%
for eq in data_dict['features']:
    print(eq['properties']['mag'])
# Out:
# 6.3
# 6.2
# 7.8
# 6.1
# 6
# 6
# 7.4
# 6.4
# 6

# %% [markdown]
# If needed, we can also convert a JSON dictionary to a pandas DataFrame using [`json_normalize`](https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html#pandas.json_normalize):

# %%
# the 'record_path' argument shows how to locate the table rows within the dict
pd.json_normalize(data_dict, record_path=['features'])
# Out:
#       type          id  properties.mag  \
# 0  Feature  us6000rcqw             6.3
# 1  Feature  us6000rcnw             6.2
# 2  Feature  us7000qx2g             7.8
# 3  Feature  us7000qx1z             6.1
# 4  Feature  us7000qwir             6.0
# 5  Feature  us7000qwch             6.0
# 6  Feature  us7000qvw5             7.4
# 7  Feature  us7000quvp             6.4
# 8  Feature  us7000qtm0             6.0
#
#                                  properties.place  properties.time  \
# 0             27 km ENE of Mene Grande, Venezuela    1758772299731
# 1             24 km ENE of Mene Grande, Venezuela    1758752515207
# 2    127 km E of Petropavlovsk-Kamchatsky, Russia    1758221893903
# 3                    28 km S of Nabire, Indonesia    1758219586543
# 4           208 km SE of Kokopo, Papua New Guinea    1758041987665
# 5  145 km ESE of Petropavlovsk-Kamchatsky, Russia    1757954076629
# 6    111 km E of Petropavlovsk-Kamchatsky, Russia    1757731074754
# 7                                  Vanuatu region    1757368068083
# 8                    87 km SW of Nikolski, Alaska    1756933066971
#
#    properties.updated properties.tz  \
# 0       1758840574774          None
# 1       1758839366726          None
# 2       1758506858065          None
# 3       1758307454420          None
# 4       1758230992147          None
# 5       1758058475804          None
# 6       1758521132567          None
# 7       1757619059254          None
# 8       1758834474454          None
#
#                                       properties.url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
# 5  https://earthquake.usgs.gov/earthquakes/eventp...
# 6  https://earthquake.usgs.gov/earthquakes/eventp...
# 7  https://earthquake.usgs.gov/earthquakes/eventp...
# 8  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                    properties.detail  properties.felt  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...            220.0  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...            242.0  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...             26.0  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...              6.0  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 5  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 6  https://earthquake.usgs.gov/fdsnws/event/1/que...             19.0  ...
# 7  https://earthquake.usgs.gov/fdsnws/event/1/que...              1.0  ...
# 8  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
#
#                                     properties.types  properties.nst  \
# 0  ,dyfi,ground-failure,impact-link,internal-mome...             107
# 1  ,dyfi,ground-failure,impact-link,internal-mome...              61
# 2  ,dyfi,finite-fault,general-text,ground-failure...             201
# 3  ,dyfi,ground-failure,internal-moment-tensor,in...              84
# 4  ,ground-failure,internal-moment-tensor,interna...             187
# 5  ,ground-failure,internal-moment-tensor,interna...             130
# 6  ,dyfi,finite-fault,general-text,ground-failure...             104
# 7  ,dyfi,ground-failure,impact-link,internal-mome...              78
# 8  ,ground-failure,impact-link,internal-moment-te...             105
#
#   properties.dmin properties.rms  properties.gap  properties.magType  \
# 0           1.038           1.09              24                 mww
# 1           1.035           1.03              55                 mww
# 2           1.136           0.85              27                 mww
# 3           1.319           0.93              36                 mww
# 4           2.048           0.74              21                 mww
# 5           1.288           0.70             105                 mww
# 6           0.995           1.11              43                 mww
# 7           5.237           0.58              52                 mww
# 8           0.812           0.73              60                 mww
#
#   properties.type                                   properties.title  \
# 0      earthquake        M 6.3 - 27 km ENE of Mene Grande, Venezuela
# 1      earthquake        M 6.2 - 24 km ENE of Mene Grande, Venezuela
# 2      earthquake  M 7.8 - 127 km E of Petropavlovsk-Kamchatsky, ...
# 3      earthquake               M 6.1 - 28 km S of Nabire, Indonesia
# 4      earthquake      M 6.0 - 208 km SE of Kokopo, Papua New Guinea
# 5      earthquake  M 6.0 - 145 km ESE of Petropavlovsk-Kamchatsky...
# 6      earthquake  M 7.4 - 111 km E of Petropavlovsk-Kamchatsky, ...
# 7      earthquake                             M 6.4 - Vanuatu region
# 8      earthquake               M 6.0 - 87 km SW of Nikolski, Alaska
#
#   geometry.type         geometry.coordinates
# 0         Point       [-70.6916, 9.9272, 14]
# 1         Point    [-70.7174, 9.9222, 7.815]
# 2         Point    [160.5129, 53.1928, 19.5]
# 3         Point      [135.5258, -3.6145, 10]
# 4         Point   [153.825, -5.4051, 41.023]
# 5         Point  [160.7026, 52.6922, 24.472]
# 6         Point  [160.2938, 53.1043, 39.465]
# 7         Point     [173.7122, -21.0251, 10]
# 8         Point     [-169.6766, 52.3338, 10]
#
# [9 rows x 30 columns]

# %% [markdown]
# # Getting Started with Pandas
# ---

# %%
import pandas as pd

# %% [markdown]
# ### Question: Planets variables
# * name - nominal
# * type - nominal
# * mass, diameter, distance_from_sun, orbital_period - continuous
# * rings - nominal (binary)

# %% [markdown]
# It will be inconvenient to work with this data table as a numpy array, because it contains both numerical and string data. Numpy arrays are restricted to a single data type.

# %%
planets = pd.read_csv('../Data/planets.csv')

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise: methods and attributes
#
# 1. What do the following methods do?
#
# [`tail`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html),
# [`sample`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html),
# [`describe`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html),
# [`copy`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.copy.html)

# %%
planets.tail() # selects the last 5 rows
# Out:
#       name         type     mass  diameter  distance_from_sun  orbital_period  \
# 3     Mars  Terrestrial    0.107     0.532               1.52            1.88
# 4  Jupiter    Gas giant  317.800    11.210               5.20           11.90
# 5   Saturn    Gas giant   95.200     9.450               9.58           29.40
# 6   Uranus    Ice giant   14.500     4.010              19.20           83.70
# 7  Neptune    Ice giant   17.100     3.880              30.05          163.70
#
#    rings
# 3  False
# 4   True
# 5   True
# 6   True
# 7   True

# %%
planets.sample() # selects one row at random
# Out:
#      name       type  mass  diameter  distance_from_sun  orbital_period  rings
# 6  Uranus  Ice giant  14.5      4.01               19.2            83.7   True

# %%
planets.describe() # calculates summary statistics
# Out:
#              mass   diameter  distance_from_sun  orbital_period
# count    8.000000   8.000000           8.000000        8.000000
# mean    55.822163   3.926750           8.457500       36.554500
# std    110.605675   4.227064          10.837813       58.705645
# min      0.055300   0.383000           0.387000        0.241000
# 25%      0.638000   0.844750           0.930750        0.903750
# 50%      7.750000   2.440000           3.360000        6.890000
# 75%     36.625000   5.370000          11.985000       42.975000
# max    317.800000  11.210000          30.050000      163.700000

# %%
planets.copy() # returns a copy of the DataFrame
# Out:
#       name         type      mass  diameter  distance_from_sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital_period  rings
# 0           0.241  False
# 1           0.615  False
# 2           1.000  False
# 3           1.880  False
# 4          11.900   True
# 5          29.400   True
# 6          83.700   True
# 7         163.700   True

# %% [markdown]
# 2. To what do the following attributes refer?
#
# [`size`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.size.html),
# [`dtypes`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html),
# [`columns`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.columns.html),
# [`values`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.values.html)

# %%
planets.size # the total number of data values (cells)
# Out:
# 56

# %%
planets.dtypes # the data type for each column
# Out:
# name                  object
# type                  object
# mass                 float64
# diameter             float64
# distance_from_sun    float64
# orbital_period       float64
# rings                   bool
# dtype: object

# %%
planets.columns # the column labels
# Out:
# Index(['name', 'type', 'mass', 'diameter', 'distance_from_sun',
#        'orbital_period', 'rings'],
#       dtype='object')

# %%
planets.values # the data values as an array
# Out:
# array([['Mercury', 'Terrestrial', 0.0553, 0.383, 0.387, 0.241, False],
#        ['Venus', 'Terrestrial', 0.815, 0.949, 0.723, 0.615, False],
#        ['Earth', 'Terrestrial', 1.0, 1.0, 1.0, 1.0, False],
#        ['Mars', 'Terrestrial', 0.107, 0.532, 1.52, 1.88, False],
#        ['Jupiter', 'Gas giant', 317.8, 11.21, 5.2, 11.9, True],
#        ['Saturn', 'Gas giant', 95.2, 9.45, 9.58, 29.4, True],
#        ['Uranus', 'Ice giant', 14.5, 4.01, 19.2, 83.7, True],
#        ['Neptune', 'Ice giant', 17.1, 3.88, 30.05, 163.7, True]],
#       dtype=object)

# %% [markdown]
# ***

# %% [markdown]
# ### Exercise: Selecting Rows
#
# 1. Select the last three rows.

# %%
planets[-3:]
# Out:
#       name       type  mass  diameter  distance_from_sun  orbital_period  \
# 5   Saturn  Gas giant  95.2      9.45               9.58            29.4
# 6   Uranus  Ice giant  14.5      4.01              19.20            83.7
# 7  Neptune  Ice giant  17.1      3.88              30.05           163.7
#
#    rings
# 5   True
# 6   True
# 7   True

# %% [markdown]
# 2. Select three rows at random.

# %%
planets.sample(3)
# Out:
#       name         type    mass  diameter  distance_from_sun  orbital_period  \
# 3     Mars  Terrestrial   0.107     0.532               1.52            1.88
# 7  Neptune    Ice giant  17.100     3.880              30.05          163.70
# 2    Earth  Terrestrial   1.000     1.000               1.00            1.00
#
#    rings
# 3  False
# 7   True
# 2  False

# %% [markdown]
# 3. Make a DataFrame containing only the first row.

# %%
planets.iloc[[0]]
# Out:
#       name         type    mass  diameter  distance_from_sun  orbital_period  \
# 0  Mercury  Terrestrial  0.0553     0.383              0.387           0.241
#
#    rings
# 0  False

# %% [markdown]
# 4. Make a DataFrame containing the first, second and last rows.

# %%
planets.iloc[[0,1,-1]]
# Out:
#       name         type     mass  diameter  distance_from_sun  orbital_period  \
# 0  Mercury  Terrestrial   0.0553     0.383              0.387           0.241
# 1    Venus  Terrestrial   0.8150     0.949              0.723           0.615
# 7  Neptune    Ice giant  17.1000     3.880             30.050         163.700
#
#    rings
# 0  False
# 1  False
# 7   True

# %% [markdown]
# ### Exercise: Selecting columns

# %% [markdown]
# 1. Select the first three rows, but only the **name** and **diameter** columns.

# %%
planets[:3][['name','diameter']]
# Out:
#       name  diameter
# 0  Mercury     0.383
# 1    Venus     0.949
# 2    Earth     1.000

# %% [markdown]
# 2. Select the first two columns for rows 4 and 6.

# %%
planets.iloc[[4,6],:2]
# Out:
#       name       type
# 4  Jupiter  Gas giant
# 6   Uranus  Ice giant

# %% [markdown]
# 3. Make a plot of `distance_from_sun` vs `orbital period`.

# %%
import matplotlib.pyplot as plt
plt.plot(planets.distance_from_sun, planets.orbital_period, marker='o')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ### Exercise: Querying and sorting data

# %% [markdown]
# 1. the terrestrial planets, ordered by increasing orbital period.

# %%
df = planets.query("type == 'Terrestrial'")
df.sort_values("orbital_period")
# Out:
#       name         type    mass  diameter  distance_from_sun  orbital_period  \
# 0  Mercury  Terrestrial  0.0553     0.383              0.387           0.241
# 1    Venus  Terrestrial  0.8150     0.949              0.723           0.615
# 2    Earth  Terrestrial  1.0000     1.000              1.000           1.000
# 3     Mars  Terrestrial  0.1070     0.532              1.520           1.880
#
#    rings
# 0  False
# 1  False
# 2  False
# 3  False

# %% [markdown]
# 2. the giant planets, ordered from largest to smallest.

# %%
df = planets.query('type in ["Gas giant","Ice giant"]')
df.sort_values('diameter',ascending=False)
# Out:
#       name       type   mass  diameter  distance_from_sun  orbital_period  \
# 4  Jupiter  Gas giant  317.8     11.21               5.20            11.9
# 5   Saturn  Gas giant   95.2      9.45               9.58            29.4
# 6   Uranus  Ice giant   14.5      4.01              19.20            83.7
# 7  Neptune  Ice giant   17.1      3.88              30.05           163.7
#
#    rings
# 4   True
# 5   True
# 6   True
# 7   True

# %% [markdown]
# 3. the planets that are more massive than Neptune.

# %%
m_neptune = planets.query('name == "Neptune"')['mass'].values[0]
planets.query('mass > @m_neptune')
# Out:
#       name       type   mass  diameter  distance_from_sun  orbital_period  \
# 4  Jupiter  Gas giant  317.8     11.21               5.20            11.9
# 5   Saturn  Gas giant   95.2      9.45               9.58            29.4
#
#    rings
# 4   True
# 5   True

# %% [markdown]
# ***

# %% [markdown]
# ### Exercise: Making new columns from existing ones

# %%
# First we compute the density in arbitrary units and add the new column

radius = planets['diameter'] / 2
vol = 4/3 * 3.14 * radius**3

mass = planets['mass']
density = mass/vol

planets['density'] = density

# %%
# Now we have to normalise by the density of Earth

d_E = planets.query('name == "Earth"')['density'].values[0]
planets['density'] = planets['density'] / d_E

# %%
planets
# Out:
#       name         type      mass  diameter  distance_from_sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital_period  rings   density
# 0           0.241  False  0.984303
# 1           0.615  False  0.953584
# 2           1.000  False  1.000000
# 3           1.880  False  0.710639
# 4          11.900   True  0.225599
# 5          29.400   True  0.112808
# 6          83.700   True  0.224872
# 7         163.700   True  0.292753

# %% [markdown]
# ---

# %%
countries = pd.read_excel("../Data/data_geographies_v1.xlsx", sheet_name = "list-of-countries-etc")

# %% [markdown]
# ### Exercise: Countries
#
# 1. Find all the countries that are south of the equator.

# %%
countries.query('Latitude < 0')
# Out:
#      geo              name four_regions       eight_regions  \
# 4    ago            Angola       africa  africa_sub_saharan
# 6    arg         Argentina     americas       america_south
# 8    aus         Australia         asia   east_asia_pacific
# 20   bol           Bolivia     americas       america_south
# 22   bwa          Botswana       africa  africa_sub_saharan
# 23   bra            Brazil     americas       america_south
# 27   bdi           Burundi       africa  africa_sub_saharan
# 34   chl             Chile     americas       america_south
# 37   com           Comoros       africa  africa_sub_saharan
# 38   cod  Congo, Dem. Rep.       africa  africa_sub_saharan
# 39   cog       Congo, Rep.       africa  africa_sub_saharan
# 50   ecu           Ecuador     americas       america_south
# 57   fji              Fiji         asia   east_asia_pacific
# 60   gab             Gabon       africa  africa_sub_saharan
# 78   idn         Indonesia         asia   east_asia_pacific
# ...

# %% [markdown]
# 2. Find the first eight African countries to join the UN.

# %%
countries.query('four_regions == "africa"') \
    .sort_values('UN member since') \
    .head(8)
# Out:
#      geo          name four_regions       eight_regions  \
# 51   egy         Egypt       africa        africa_north
# 98   lbr       Liberia       africa  africa_sub_saharan
# 161  zaf  South Africa       africa  africa_sub_saharan
# 56   eth      Ethiopia       africa  africa_sub_saharan
# 99   lby         Libya       africa        africa_north
# 119  mar       Morocco       africa        africa_north
# 164  sdn         Sudan       africa  africa_sub_saharan
# 178  tun       Tunisia       africa        africa_north
#
#                   six_regions members_oecd_g77  Latitude  Longitude  \
# 51   middle_east_north_africa              g77      27.0       30.0
# 98         sub_saharan_africa              g77       6.5       -9.5
# 161        sub_saharan_africa              g77     -29.0       24.0
# 56         sub_saharan_africa              g77       9.0       39.5
# 99   middle_east_north_africa              g77      28.0       17.0
# ...

# %% [markdown]
# 3. Make an array of OECD country names, sorted from East to West.

# %%
df = countries.query('members_oecd_g77 == "oecd"') \
    .sort_values('Longitude', ascending=False)
a = df['name'].values
a
# Out:
# array(['New Zealand', 'Japan', 'Australia', 'South Korea', 'Turkey',
#        'Finland', 'Greece', 'Hungary', 'Poland', 'Slovak Republic',
#        'Czech Republic', 'Sweden', 'Austria', 'Italy', 'Germany',
#        'Denmark', 'Norway', 'Switzerland', 'Luxembourg', 'Netherlands',
#        'Belgium', 'France', 'United Kingdom', 'Spain', 'Ireland',
#        'Portugal', 'Iceland', 'United States', 'Mexico', 'Canada'],
#       dtype=object)
